# %%
import numpy as np
import nibabel as nib
import nitransforms

# %%
f = '/Users/tsalo/Documents/Laird_DIVA/dset/sub-Blossom/ses-02/func/sub-Blossom_ses-02_task-PST_run-1_echo-2_bold.nii.gz'
img = nib.load(f)

# %%
motpars = np.random.random((img.shape[-1], 6))

# %%
help(nitransforms.linear.LinearTransformsMapping)
# Out:
# Help on class LinearTransformsMapping in module nitransforms.linear:
#
# class LinearTransformsMapping(Affine)
#  |  Represents a series of linear transforms.
#  |
#  |  Method resolution order:
#  |      LinearTransformsMapping
#  |      Affine
#  |      nitransforms.base.TransformBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, i)
#  |      Enable indexed access to the series of matrices.
#  |
#  |  __init__(self, transforms, reference=None)
#  |      Initialize a linear transform mapping.
#  |
#  |      Parameters
#  |      ----------
#  |      transforms : :obj:`list`
#  |          The inverse coordinate transformation matrix **in physical
#  |          coordinates**, mapping coordinates from *reference* space
#  |          into *moving* space.
#  |          This matrix should be provided in homogeneous coordinates.
#  |
#  |      Examples
#  |      --------
#  |      >>> xfm = LinearTransformsMapping([
# ...
